# %% [markdown]
# <a href="https://colab.research.google.com/github/ayanga1998/UFC_Dashboard/blob/main/Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # UFC Dataset Cleaning
#
# The purpose of this notebook is to establish set functions to clean the data we collected from the UFC Stats website and convert the raw data into information we can use for processing.

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('Data/full_ufc_dataset.csv', index_col=[0])

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6439 entries, 0 to 6438
# Data columns (total 38 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   red_fighter     6439 non-null   object
#  1   blue_fighter    6439 non-null   object
#  2   red_kd          6439 non-null   int64
#  3   blue_kd         6439 non-null   int64
#  4   red_ss          6439 non-null   object
#  5   blue_ss         6439 non-null   object
#  6   red_ss_pct      6439 non-null   object
#  7   blue_ss_pct     6439 non-null   object
#  8   red_ts          6439 non-null   object
#  9   blue_ts         6439 non-null   object
#  10  red_td          6439 non-null   object
#  11  blue_td         6439 non-null   object
#  12  red_td_pct      6439 non-null   object
#  13  blue_td_pct     6439 non-null   object
#  14  red_sub_att     6439 non-null   int64
#  15  blue_sub_att    6439 non-null   int64
#  16  red_rev         6439 non-null   int64
#  17  blue_rev        6439 non-null   int64
#  18  red_ctrl_time   6439 non-null   object
#  19  blue_ctrl_time  6439 non-null   object
#  20  red_head        6439 non-null   object
#  21  blue_head       6439 non-null   object
#  22  red_body        6439 non-null   object
#  23  blue_body       6439 non-null   object
#  24  red_leg         6439 non-null   object
#  25  blue_leg        6439 non-null   object
#  26  red_dist        6439 non-null   object
#  27  blue_dist       6439 non-null   object
#  28  red_clinch      6439 non-null   object
#  29  blue_clinch     6439 non-null   object
#  30  red_grnd        6439 non-null   object
#  31  blue_grnd       6439 non-null   object
#  32  result          6439 non-null   object
#  33  method          6439 non-null   object
#  34  round           6439 non-null   object
#  35  time            6439 non-null   object
#  36  event_title     6439 non-null   object
#  37  weight_class    6439 non-null   object
# dtypes: int64(6), object(32)
# memory usage: 1.9+ MB

# %% [markdown]
# **Key**
#
# kd: knockdowns \
# ss: significant strikes \
# td: takedowns \
# rev: ? \

# %%
dataset['event_title'] = dataset.event_title.apply(lambda x: x.split('  ')[1].replace('\n','').strip())
dataset['weight_class'] = dataset.weight_class.apply(lambda x: x.strip().replace('\n',''))

# %%
dataset.head(30)
# Out:
#              red_fighter          blue_fighter  red_kd  blue_kd      red_ss  \
# 0        Jack Hermansson       Sean Strickland       0        0  137 of 353
# 1       Punahele Soriano          Nick Maximov       0        0    45 of 63
# 2      Shavkat Rakhmonov       Carlston Harris       1        0    13 of 28
# 3              Sam Alvey         Brendan Allen       0        1    24 of 57
# 4           Tresean Gore          Bryan Battle       0        0    57 of 95
# 5           Julian Erosa       Steven Peterson       0        0  155 of 291
# 6            Miles Johns        John Castaneda       0        1    34 of 85
# 7          Hakeem Dawodu       Michael Trizano       0        0  141 of 214
# 8         Chidi Njokuani  Marc-Andre Barriault       1        0    11 of 11
# 9           Alexis Davis    Julija Stoliarenko       0        0   85 of 120
# 10       Jailton Almeida        Danilo Marques       0        0    30 of 51
# 11            Jason Witt             Phil Rowe       0        1     8 of 22
# 12        Malcolm Gordon          Denys Bondar       0        0     3 of 11
# 13       Francis Ngannou            Ciryl Gane       0        0   43 of 104
# 14        Brandon Moreno   Deiveson Figueiredo       0        3  105 of 259
# 15        Michel Pereira          Andre Fialho       0        0  107 of 202
# 16          Cody Stamann     Said Nurmagomedov       0        0      1 of 4
# 17       Michael Morales          Trevin Giles       1        0    26 of 42
# 18        Raoni Barcelos          Victor Henry       0        0  134 of 277
# 19  Jack Della Maddalena        Pete Rodriguez       1        0    43 of 81
# 20          Tony Gravely       Saimon Oliveira       0        0    46 of 99
# 21          Matt Frevola         Genaro Valdez       4        0   60 of 101
# 22  Silvana Gomez Juarez    Vanessa Demopoulos       1        0    10 of 18
# 23            Kay Hansen  Jasmine Jasudavicius       0        0   44 of 101
# 24         Calvin Kattar         Giga Chikadze       1        0  144 of 402
# 25          Jake Collier         Chase Sherman       0        0    20 of 49
# 26        Brandon Royval      Rogerio Bontorin       0        0   40 of 132
# 27     Katlyn Chookagian         Jennifer Maia       0        0   72 of 177
# 28           Dakota Bush  Viacheslav Borshchev       0        1    11 of 30
# 29            Bill Algeo      Joanderson Brito       0        0   59 of 118
#
#        blue_ss red_ss_pct blue_ss_pct      red_ts     blue_ts  ... red_clinch  \
# 0   153 of 330        38%         46%  137 of 353  161 of 338  ...     3 of 3
# 1     29 of 45        71%         64%    74 of 93    60 of 82  ...     2 of 2
# 2     10 of 27        46%         37%    16 of 31    15 of 35  ...     0 of 0
# 3     36 of 54        42%         66%    24 of 57    36 of 54  ...     0 of 1
# 4   112 of 193        60%         58%   86 of 126  119 of 203  ...   11 of 12
# 5   148 of 247        53%         59%  163 of 300  174 of 276  ...    9 of 16
# 6    58 of 147        40%         39%    34 of 85   68 of 159  ...     1 of 2
# 7    70 of 133        65%         52%  189 of 266   94 of 158  ...   18 of 19
# 8       2 of 2       100%        100%    13 of 13      2 of 2  ...     0 of 0
# 9    56 of 113        70%         49%  171 of 218   93 of 154  ...     1 of 1
# 10      0 of 0        58%         ---    37 of 60      2 of 2  ...     0 of 0
# 11     8 of 17        36%         47%    25 of 43     8 of 17  ...     0 of 1
# 12      4 of 5        27%         80%     6 of 15      4 of 5  ...     0 of 0
# 13    63 of 91        41%         69%   71 of 139   79 of 107  ...    6 of 10
# 14   86 of 169        40%         50%  106 of 260   95 of 178  ...     5 of 7
# 15   45 of 135        52%         33%  112 of 209   48 of 138  ...   11 of 14
# 16     7 of 13        25%         53%      1 of 4     7 of 13  ...     0 of 0
# 17     8 of 15        61%         53%    28 of 44     8 of 15  ...     0 of 0
# 18  181 of 352        48%         51%  134 of 277  222 of 397  ...     8 of 8
# 19    25 of 69        53%         36%    43 of 81    25 of 69  ...     0 of 0
# 20    35 of 71        46%         49%   66 of 132    50 of 87  ...     4 of 7
# 21    10 of 38        59%         26%   71 of 114    10 of 38  ...    6 of 15
# 22     4 of 12        55%         33%    10 of 18     4 of 12  ...     0 of 0
# 23   50 of 110        43%         45%   52 of 112   99 of 165  ...     3 of 4
# 24  128 of 347        35%         36%  157 of 418  129 of 348  ...     2 of 2
# 25    10 of 17        40%         58%    20 of 50    10 of 17  ...     0 of 0
# 26    28 of 58        30%         48%   81 of 174    39 of 71  ...     1 of 1
# 27   52 of 171        40%         30%   81 of 188   60 of 180  ...     4 of 6
# 28    16 of 27        36%         59%    11 of 30    17 of 28  ...     2 of 2
# 29   40 of 104        50%         38%  112 of 176   46 of 110  ...   17 of 23
#
#    blue_clinch  red_grnd blue_grnd                 result  \
# 0       2 of 2    0 of 0    0 of 0       Sean Strickland
# 1     10 of 10  23 of 23    4 of 4          Nick Maximov
# 2       2 of 2    4 of 8    0 of 0     Shavkat Rakhmonov
# 3       2 of 3    0 of 0    2 of 4         Brendan Allen
# 4       7 of 8    4 of 4    0 of 0          Bryan Battle
# 5     15 of 19    5 of 5    0 of 1          Julian Erosa
# 6      7 of 11    0 of 0    4 of 7        John Castaneda
# 7     16 of 23    0 of 0    0 of 0         Hakeem Dawodu
# 8       0 of 0    7 of 7    0 of 0        Chidi Njokuani
# 9       1 of 1  43 of 55    4 of 4          Alexis Davis
# 10      0 of 0  30 of 50    0 of 0       Jailton Almeida
# 11      1 of 1    1 of 1    2 of 2             Phil Rowe
# 12      0 of 0    0 of 0    0 of 0        Malcolm Gordon
# 13      6 of 7    3 of 7    0 of 0       Francis Ngannou
# 14      5 of 7    0 of 0    1 of 2   Deiveson Figueiredo
# 15      7 of 7    0 of 0    2 of 6        Michel Pereira
# 16      0 of 0    0 of 0    0 of 0     Said Nurmagomedov
# 17      0 of 0  14 of 18    0 of 0       Michael Morales
# 18    18 of 27    1 of 2    0 of 0          Victor Henry
# 19      0 of 0    3 of 3    0 of 0  Jack Della Maddalena
# 20      8 of 9  18 of 42    0 of 0          Tony Gravely
# 21     3 of 11  43 of 59    0 of 0          Matt Frevola
# 22      0 of 0   7 of 12    0 of 0    Vanessa Demopoulos
# 23     8 of 13    0 of 1  15 of 18  Jasmine Jasudavicius
# 24      1 of 3   7 of 10    0 of 0         Calvin Kattar
# 25      0 of 0   8 of 13    0 of 0          Jake Collier
# 26      0 of 0  11 of 28    1 of 6        Brandon Royval
# 27      4 of 4    0 of 0    0 of 0     Katlyn Chookagian
# 28      4 of 4    1 of 1    6 of 8  Viacheslav Borshchev
# 29      1 of 6  10 of 10    0 of 1            Bill Algeo
#
#                     method                                              round  \
# 0        Decision - Split   \n\n          Round:\n        \n        5\n
# 1        Decision - Split   \n\n          Round:\n        \n        3\n
# 2                  KO/TKO   \n\n          Round:\n        \n        1\n
# 3              Submission   \n\n          Round:\n        \n        2\n
# 4    Decision - Unanimous   \n\n          Round:\n        \n        3\n
# 5        Decision - Split   \n\n          Round:\n        \n        3\n
# 6              Submission   \n\n          Round:\n        \n        3\n
# 7    Decision - Unanimous   \n\n          Round:\n        \n        3\n
# 8                  KO/TKO   \n\n          Round:\n        \n        1\n
# 9    Decision - Unanimous   \n\n          Round:\n        \n        3\n
# 10                 KO/TKO   \n\n          Round:\n        \n        1\n
# 11                 KO/TKO   \n\n          Round:\n        \n        2\n
# 12                 KO/TKO   \n\n          Round:\n        \n        1\n
# 13   Decision - Unanimous   \n\n          Round:\n        \n        5\n
# 14   Decision - Unanimous   \n\n          Round:\n        \n        5\n
# 15   Decision - Unanimous   \n\n          Round:\n        \n        3\n
# 16             Submission   \n\n          Round:\n        \n        1\n
# 17                 KO/TKO   \n\n          Round:\n        \n        1\n
# 18   Decision - Unanimous   \n\n          Round:\n        \n        3\n
# 19                 KO/TKO   \n\n          Round:\n        \n        1\n
# 20   Decision - Unanimous   \n\n          Round:\n        \n        3\n
# 21                 KO/TKO   \n\n          Round:\n        \n        1\n
# 22             Submission   \n\n          Round:\n        \n        1\n
# 23   Decision - Unanimous   \n\n          Round:\n        \n        3\n
# 24   Decision - Unanimous   \n\n          Round:\n        \n        5\n
# 25             Submission   \n\n          Round:\n        \n        1\n
# 26       Decision - Split   \n\n          Round:\n        \n        3\n
# 27   Decision - Unanimous   \n\n          Round:\n        \n        3\n
# 28                 KO/TKO   \n\n          Round:\n        \n        1\n
# 29   Decision - Unanimous   \n\n          Round:\n        \n        3\n
#
#                                                  time  \
# 0   \n\n          Time:\n        \n        5:00\n\...
# 1   \n\n          Time:\n        \n        5:00\n\...
# 2   \n\n          Time:\n        \n        4:10\n\...
# 3   \n\n          Time:\n        \n        2:10\n\...
# 4   \n\n          Time:\n        \n        5:00\n\...
# 5   \n\n          Time:\n        \n        5:00\n\...
# 6   \n\n          Time:\n        \n        1:38\n\...
# 7   \n\n          Time:\n        \n        5:00\n\...
# 8   \n\n          Time:\n        \n        0:16\n\...
# 9   \n\n          Time:\n        \n        5:00\n\...
# 10  \n\n          Time:\n        \n        2:57\n\...
# 11  \n\n          Time:\n        \n        2:15\n\...
# 12  \n\n          Time:\n        \n        1:22\n\...
# 13  \n\n          Time:\n        \n        5:00\n\...
# 14  \n\n          Time:\n        \n        5:00\n\...
# 15  \n\n          Time:\n        \n        5:00\n\...
# 16  \n\n          Time:\n        \n        0:47\n\...
# 17  \n\n          Time:\n        \n        4:06\n\...
# 18  \n\n          Time:\n        \n        5:00\n\...
# 19  \n\n          Time:\n        \n        2:59\n\...
# 20  \n\n          Time:\n        \n        5:00\n\...
# 21  \n\n          Time:\n        \n        3:15\n\...
# 22  \n\n          Time:\n        \n        2:25\n\...
# 23  \n\n          Time:\n        \n        5:00\n\...
# 24  \n\n          Time:\n        \n        5:00\n\...
# 25  \n\n          Time:\n        \n        2:26\n\...
# 26  \n\n          Time:\n        \n        5:00\n\...
# 27  \n\n          Time:\n        \n        5:00\n\...
# 28  \n\n          Time:\n        \n        3:47\n\...
# 29  \n\n          Time:\n        \n        5:00\n\...
#
#                                    event_title                weight_class
# 0   UFC Fight Night: Hermansson vs. Strickland           Middleweight Bout
# 1   UFC Fight Night: Hermansson vs. Strickland           Middleweight Bout
# 2   UFC Fight Night: Hermansson vs. Strickland           Welterweight Bout
# 3   UFC Fight Night: Hermansson vs. Strickland      Light Heavyweight Bout
# 4   UFC Fight Night: Hermansson vs. Strickland           Middleweight Bout
# 5   UFC Fight Night: Hermansson vs. Strickland          Featherweight Bout
# 6   UFC Fight Night: Hermansson vs. Strickland           Bantamweight Bout
# 7   UFC Fight Night: Hermansson vs. Strickland          Featherweight Bout
# 8   UFC Fight Night: Hermansson vs. Strickland           Middleweight Bout
# 9   UFC Fight Night: Hermansson vs. Strickland   Women's Bantamweight Bout
# 10  UFC Fight Night: Hermansson vs. Strickland      Light Heavyweight Bout
# 11  UFC Fight Night: Hermansson vs. Strickland           Welterweight Bout
# 12  UFC Fight Night: Hermansson vs. Strickland              Flyweight Bout
# 13                   UFC 270: Ngannou vs. Gane  UFC Heavyweight Title Bout
# 14                   UFC 270: Ngannou vs. Gane    UFC Flyweight Title Bout
# 15                   UFC 270: Ngannou vs. Gane           Welterweight Bout
# 16                   UFC 270: Ngannou vs. Gane           Bantamweight Bout
# 17                   UFC 270: Ngannou vs. Gane           Welterweight Bout
# 18                   UFC 270: Ngannou vs. Gane           Bantamweight Bout
# 19                   UFC 270: Ngannou vs. Gane           Welterweight Bout
# 20                   UFC 270: Ngannou vs. Gane           Bantamweight Bout
# 21                   UFC 270: Ngannou vs. Gane            Lightweight Bout
# 22                   UFC 270: Ngannou vs. Gane    Women's Strawweight Bout
# 23                   UFC 270: Ngannou vs. Gane      Women's Flyweight Bout
# 24        UFC Fight Night: Kattar vs. Chikadze          Featherweight Bout
# 25        UFC Fight Night: Kattar vs. Chikadze            Heavyweight Bout
# 26        UFC Fight Night: Kattar vs. Chikadze              Flyweight Bout
# 27        UFC Fight Night: Kattar vs. Chikadze      Women's Flyweight Bout
# 28        UFC Fight Night: Kattar vs. Chikadze            Lightweight Bout
# 29        UFC Fight Night: Kattar vs. Chikadze          Featherweight Bout
#
# [30 rows x 38 columns]

# %%
def string_to_num(data, colname):
    ''' 
    Clean columns associated with string i.e. (4 of 15 strikes) and create 
    separate columns for strikes thrown and landed respectively 
    '''

    col_thrown = colname + '_thrown'
    col_landed = colname + '_landed'
    
    thrown = data[colname].apply(lambda x: int(x.replace('of', '').split()[1]))
    landed = data[colname].apply(lambda x: int(x.replace('of', '').split()[0]))

    data[col_thrown] = thrown 
    data[col_landed] = landed
    
    data = data.drop(colname, axis=1)

    return data

def clean_pct(data, col):
    '''Clean columns associated with percentages'''

    data[col] = data[col].apply(lambda x: int(x.replace('%', '').replace('---', '0').strip())/100)

    return data

def clean_ctrl_time(data):
    if '--' in data:
        time = int(data.strip().replace('--', '0'))
    else:
        time = data.strip().split(':')
        time = int(time[0])*60 + int(time[1])
    
    return time

def get_seconds(value):
    time_list = value.replace('Time:','').replace('\n','').strip().split(':')
    time = int(time_list[0])*60 + int(time_list[1])
    return time

# %%
df = dataset

# Extract strikes thrown and landed and store into columns
cols = ['red_ss', 'blue_ss', 'red_ts', 'blue_ts', 'red_td', 'blue_td', 
        'red_head', 'blue_head', 'red_body', 'blue_body', 'red_leg', 'blue_leg', 'red_dist', 'blue_dist',
        'red_clinch', 'blue_clinch', 'red_grnd', 'blue_grnd']

for col in cols:
    df = string_to_num(df, col)


# Clean percentage columns
pct_cols = ['red_ss_pct', 'blue_ss_pct', 'red_td_pct', 'blue_td_pct']

for col in pct_cols:
    df = clean_pct(df, col)


# Clean round data
df['round'] = df['round'].apply(lambda x: int(x.replace('\n','').replace('Round:', '').strip()))


# Clean control time columns
ctrl_cols = ['red_ctrl_time', 'blue_ctrl_time']

for col in ctrl_cols:
    df[col] = df[col].apply(lambda x: clean_ctrl_time(x))


# Clean time column (convert to seconds)
df['time'] = df['time'].apply(lambda x: get_seconds(x))

# Strip leading/trailing whitespace in result
df['result'] = df['result'].apply(lambda x: x.strip())

# Calculate total fight time in seconds
df['fight_time'] = (df['round']-1)*300 + df['time']

# %%
# Rename columns for better clarity
col_list = {col:col.replace('thrown','att') for col in list(df.columns) if 'thrown' in col}
df = df.rename(col_list, axis=1)

# %%
# Extract title bought from weight class
df['title_bout'] = 0
df.loc[df['weight_class'].str.contains('Title'), 'title_bout'] = 1

# %%
df['weight_class'] = df.weight_class.apply(lambda x: x.replace('Bout',''))
df['weight_class'] = df.weight_class.apply(lambda x: x.replace('UFC',''))
df['weight_class'] = df.weight_class.apply(lambda x: x.replace('Title',''))

# %%
df['method'].value_counts()
# Out:
#  Decision - Unanimous        2263
#  KO/TKO                      2043
#  Submission                  1276
#  Decision - Split             610
#  TKO - Doctor's Stoppage       84
#  Decision - Majority           73
#  Overturned                    49
#  Could Not Continue            19
#  DQ                            19
#  Other                          3
# Name: method, dtype: int64

# %%
def clean_method(text):
    
    if 'Decision' in text:
        text = text.split('-')[0].strip()
    else: text.strip()
        
    return text

# %%
df['method'] = df['method'].apply(lambda x: clean_method(x))

# %%
df['method'].value_counts()
# Out:
# Decision                     2946
#  KO/TKO                      2043
#  Submission                  1276
#  TKO - Doctor's Stoppage       84
#  Overturned                    49
#  Could Not Continue            19
#  DQ                            19
#  Other                          3
# Name: method, dtype: int64

# %%
df['method']
# Out:
# 0           Decision
# 1           Decision
# 2            KO/TKO
# 3        Submission
# 4           Decision
#             ...
# 6434         KO/TKO
# 6435     Submission
# 6436         KO/TKO
# 6437     Submission
# 6438     Submission
# Name: method, Length: 6439, dtype: object

# %% [markdown]
# # Connecting the fight data with event specific data

# %%
event_df = pd.read_csv('Data/event_data.csv', index_col=0)
#event_df['event_title'] = event_df.event_title.apply(lambda x: x.split(':')[0].strip())
event_df.head()
# Out:
#                                   event_title        date  \
# 0            UFC Fight Night: Walker vs. Hill  19-2022-02
# 1           UFC 271: Adesanya vs. Whittaker 2  12-2022-02
# 2  UFC Fight Night: Hermansson vs. Strickland  05-2022-02
# 3                   UFC 270: Ngannou vs. Gane  22-2022-01
# 4        UFC Fight Night: Kattar vs. Chikadze  15-2022-01
#
#                    location
# 0    Las Vegas, Nevada, USA
# 1       Houston, Texas, USA
# 2    Las Vegas, Nevada, USA
# 3  Anaheim, California, USA
# 4    Las Vegas, Nevada, USA

# %%
event_df.event_title.value_counts()
# Out:
# UFC Fight Night 3                               1
# UFC 156: Aldo vs Edgar                          1
# UFC 257: Poirier vs. McGregor                   1
# UFC Fight Night: Arlovski vs. Barnett           1
# UFC Fight Night: Edgar vs. The Korean Zombie    1
#                                                ..
# UFC Fight Night: Gustafsson vs. Smith           1
# UFC Fight Night: Edgar vs Faber                 1
# UFC 20: Battle for the Gold                     1
# UFC 43: Meltdown                                1
# UFC Fight Night: Teixeira vs Bader              1
# Name: event_title, Length: 593, dtype: int64

# %%
df = pd.merge(df, event_df, on='event_title', how='inner')

# %%
df['event_title'] = df.event_title.apply(lambda x: x.split(':')[0].strip())

# %%
df
# Out:
#             red_fighter      blue_fighter  red_kd  blue_kd  red_ss_pct  \
# 0       Jack Hermansson   Sean Strickland       0        0        0.38
# 1      Punahele Soriano      Nick Maximov       0        0        0.71
# 2     Shavkat Rakhmonov   Carlston Harris       1        0        0.46
# 3             Sam Alvey     Brendan Allen       0        1        0.42
# 4          Tresean Gore      Bryan Battle       0        0        0.60
# ...                 ...               ...     ...      ...         ...
# 6434       Orlando Wiet  Robert Lucarelli       0        0        0.66
# 6435      Frank Hamaker   Thaddeus Luster       0        0        0.66
# 6436      Johnny Rhodes     David Levicki       0        0        0.64
# 6437      Patrick Smith        Ray Wizard       0        0        1.00
# 6438       Scott Morris    Sean Daugherty       0        0        1.00
#
#       blue_ss_pct  red_td_pct  blue_td_pct  red_sub_att  blue_sub_att  ...  \
# 0            0.46        0.00         0.00            0             0  ...
# 1            0.64        0.00         0.68            0             1  ...
# 2            0.37        0.33         0.00            0             0  ...
# 3            0.66        0.00         0.00            0             1  ...
# 4            0.58        0.66         0.12            1             0  ...
# ...           ...         ...          ...          ...           ...  ...
# 6434         0.33        0.00         1.00            0             1  ...
# 6435         0.00        1.00         0.00            3             0  ...
# 6436         0.80        1.00         0.00            0             0  ...
# 6437         1.00        0.00         0.00            1             0  ...
# 6438         0.00        1.00         0.00            1             0  ...
#
#       blue_clinch_att  blue_clinch_landed  red_grnd_att  red_grnd_landed  \
# 0                   2                   2             0                0
# 1                  10                  10            23               23
# 2                   2                   2             8                4
# 3                   3                   2             0                0
# 4                   8                   7             4                4
# ...               ...                 ...           ...              ...
# 6434                0                   0             9                7
# 6435                0                   0             2                1
# 6436                2                   2            15                9
# 6437                0                   0             0                0
# 6438                1                   0             0                0
#
#      blue_grnd_att blue_grnd_landed  fight_time  title_bout        date  \
# 0                0                0        1500           0  05-2022-02
# 1                4                4         900           0  05-2022-02
# 2                0                0         250           0  05-2022-02
# 3                4                2         430           0  05-2022-02
# 4                0                0         900           0  05-2022-02
# ...            ...              ...         ...         ...         ...
# 6434             0                0         170           0  11-1994-03
# 6435             0                0         292           0  11-1994-03
# 6436             1                1         733           0  11-1994-03
# 6437             0                0          58           0  11-1994-03
# 6438             0                0          20           0  11-1994-03
#
#                     location
# 0     Las Vegas, Nevada, USA
# 1     Las Vegas, Nevada, USA
# 2     Las Vegas, Nevada, USA
# 3     Las Vegas, Nevada, USA
# 4     Las Vegas, Nevada, USA
# ...                      ...
# 6434   Denver, Colorado, USA
# 6435   Denver, Colorado, USA
# 6436   Denver, Colorado, USA
# 6437   Denver, Colorado, USA
# 6438   Denver, Colorado, USA
#
# [6439 rows x 60 columns]

# %%
df.to_csv('Data/UFC_dataset_clean.csv')
